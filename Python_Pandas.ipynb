# %% [markdown]
# ## Links
# https://pandas.pydata.org/docs/getting_started/intro_tutorials/01_table_oriented.html
# https://treemaps.openapc.net/

# %%
import urllib.request
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/OpenAPC/openapc-de/master/data/fuberlin/APC_FU_Berlin_2015.csv"
apc_file = "openapc.csv"

# %%
# Download der Daten und lokales Speichern
urllib.request.urlretrieve(url, apc_file)
# Out:
# ('openapc.csv', <http.client.HTTPMessage at 0x28858235550>)

# %%
apcs = pd.read_csv(apc_file)

# %%
apcs = pd.read_csv("openapc.csv")

# %%
apcs
# Out:
#    institution  period     euro                           doi  is_hybrid  \
# 0    FU Berlin    2015  2000.00         10.1038/npjqi.2015.10      False
# 1    FU Berlin    2015  1503.12     10.1103/PhysRevX.5.041008      False
# 2    FU Berlin    2015  2000.00            10.1038/ncomms9498      False
# 3    FU Berlin    2015  2000.00  10.1371/journal.ppat.1005246      False
# 4    FU Berlin    2015  1805.00     10.1186/s13099-015-0075-z      False
# ..         ...     ...      ...                           ...        ...
# 56   FU Berlin    2015  1731.45     10.1186/s13015-014-0028-y      False
# 57   FU Berlin    2015  1600.00      10.3389/fpsyg.2015.00194      False
# 58   FU Berlin    2015   219.84       10.3389/fevo.2015.00020      False
# 59   FU Berlin    2015  1386.35             10.1038/srep19416      False
# 60   FU Berlin    2015  2000.00           10.1155/2015/569512      False
#
#                            publisher                  journal_full_title  \
# ...

# %%
# max Zeilenanzahl anpassen
# pd.set_option(display.max.rows)

# %%
apcs.head(5)
# Out:
#   institution  period     euro                           doi  is_hybrid  \
# 0   FU Berlin    2015  2000.00         10.1038/npjqi.2015.10      False
# 1   FU Berlin    2015  1503.12     10.1103/PhysRevX.5.041008      False
# 2   FU Berlin    2015  2000.00            10.1038/ncomms9498      False
# 3   FU Berlin    2015  2000.00  10.1371/journal.ppat.1005246      False
# 4   FU Berlin    2015  1805.00     10.1186/s13099-015-0075-z      False
#
#                           publisher       journal_full_title       issn  \
# 0                   Springer Nature  npj Quantum Information  2056-6387
# 1   American Physical Society (APS)        Physical Review X  2160-3308
# 2                   Springer Nature    Nature Communications  2041-1723
# 3  Public Library of Science (PLoS)           PLOS Pathogens  1553-7374
# 4                   Springer Nature            Gut Pathogens  1757-4749
#
#   issn_print issn_electronic                                  license_ref  \
# ...

# %%
# shape == Attribut (wie Methoden ohne ())
apcs.shape
# Out:
# (61, 17)

# %%
# liste mit allen Spalten
apcs.columns
# Out:
# Index(['institution', 'period', 'euro', 'doi', 'is_hybrid', 'publisher',
#        'journal_full_title', 'issn', 'issn_print', 'issn_electronic',
#        'license_ref', 'indexed_in_crossref', 'pmid', 'pmcid', 'ut', 'url',
#        'doaj'],
#       dtype='object')

# %%
# Spalten über Spaltennamen
apcs["euro"]
# Out:
# 0     2000.00
# 1     1503.12
# 2     2000.00
# 3     2000.00
# 4     1805.00
#        ...
# 56    1731.45
# 57    1600.00
# 58     219.84
# 59    1386.35
# 60    2000.00
# Name: euro, Length: 61, dtype: float64

# %%
apcs["euro"].describe()
# Out:
# count      61.000000
# mean     1419.608033
# std       456.811349
# min       219.840000
# 25%      1178.420000
# 50%      1410.070000
# 75%      1800.000000
# max      2000.000000
# Name: euro, dtype: float64

# %%
apcs["euro"].max()
# Out:
# np.float64(2000.0)

# %%
apcs["euro"].min()
# Out:
# np.float64(219.84)

# %%
apcs["euro"].median()
# Out:
# np.float64(1410.07)

# %%
apcs["euro"] >= 2000
# Out:
# 0      True
# 1     False
# 2      True
# 3      True
# 4     False
#       ...
# 56    False
# 57    False
# 58    False
# 59    False
# 60     True
# Name: euro, Length: 61, dtype: bool

# %%
# Dataframe - Spalte - Bedingung
apcs[apcs["euro"] >= 2000]
# Out:
#    institution  period    euro                            doi  is_hybrid  \
# 0    FU Berlin    2015  2000.0          10.1038/npjqi.2015.10      False
# 2    FU Berlin    2015  2000.0             10.1038/ncomms9498      False
# 3    FU Berlin    2015  2000.0   10.1371/journal.ppat.1005246      False
# 12   FU Berlin    2015  2000.0       10.3389/fpsyg.2015.01675      False
# 15   FU Berlin    2015  2000.0   10.1371/journal.ppat.1004781      False
# 23   FU Berlin    2015  2000.0         10.1127/metz/2015/0641      False
# 28   FU Berlin    2015  2000.0       10.3389/fnhum.2015.00551      False
# 29   FU Berlin    2015  2000.0             10.1038/ncomms8606      False
# 32   FU Berlin    2015  2000.0      10.1186/s12918-015-0183-x      False
# 45   FU Berlin    2015  2000.0   10.1371/journal.pcbi.1004200      False
# 60   FU Berlin    2015  2000.0            10.1155/2015/569512      False
#
#                            publisher               journal_full_title  \
# ...

# %%
# Dataframe - Spalte - Bedingung
apcs_2000 = apcs[apcs["euro"] >= 2000]

# %%
apcs_2000.to_csv("openapc_2000.csv")

# %%
# !pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    ----- ---------------------------------- 1.0/7.8 MB 7.1 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.1/7.8 MB 6.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 3.4/7.8 MB 6.1 MB/s eta 0:00:01
#    ------------------------ --------------- 4.7/7.8 MB 6.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.8/7.8 MB 6.1 MB/s eta 0:00:01
#    ------------------------------------ --- 7.1/7.8 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------- 7.8/7.8 MB 6.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ----------------------- ---------------- 1.3/2.2 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 5.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    -------------------- ------------------- 1.3/2.6 MB 6.1 MB/s eta 0:00:01
# ...

# %%
apcs["euro"].hist()
# Out:
# <Axes: >

# %%
apcs["euro"].hist(bins=20, color="black")
# Out:
# <Axes: >

# %%
hist_euro = apcs["euro"].hist(bins=20, color="black")

# %%
figure = hist_euro.get_figure()

# %%
figure.savefig("apc_hist.png")
